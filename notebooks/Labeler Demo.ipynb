# %%
import matplotlib.pyplot as plt
from ipywidgets import widgets

# %%
from aco import ACOio, datetime, timedelta, Sound, ACO
# %matplotlib inline

loader = ACOio('/home/probinso/git/Whales/raw')
target = datetime(
    day=18, month=2, year=2016,
    hour=8, minute=15
)

# original audio
src = loader.load(target)[:timedelta(seconds=30)]
src.View()
plt.title('Raw')
src.Listen()
# Out:
# /home/probinso/git/CURRENT/ACOio/aco.py:249: UserWarning: Overlaps 7196672 samples
#   warnings.warn(f'Overlaps {overlap_count} samples', UserWarning)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = []
y = []
for snd in src.chunk(timedelta(seconds=2), timedelta(seconds=2)):
    box = widgets.Checkbox(
        value=False,
        description='Whale',
        disabled=False
    )

    x.append(snd)
    y.append(box)
    
    noise = snd[
        timedelta(seconds=0.0):
        timedelta(seconds=0.2)
    ]
    clean = snd.subtract(noise)
    clean.View()
    plt.show()
    display(snd.Listen(), box)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Checkbox(value=False, description='Whale')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Checkbox(value=False, description='Whale')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Checkbox(value=False, description='Whale')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Checkbox(value=False, description='Whale')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Checkbox(value=False, description='Whale')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Checkbox(value=False, description='Whale')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Checkbox(value=False, description='Whale')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Checkbox(value=False, description='Whale')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Checkbox(value=False, description='Whale')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Checkbox(value=False, description='Whale')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Checkbox(value=False, description='Whale')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Checkbox(value=False, description='Whale')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Checkbox(value=False, description='Whale')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Checkbox(value=False, description='Whale')

# %%
def save_contents():
    global y
    _ = map(lambda box: int(box.value), y)

    for snd, label in zip(x, _):
        snd.save(label)

# %%
save_contents()
